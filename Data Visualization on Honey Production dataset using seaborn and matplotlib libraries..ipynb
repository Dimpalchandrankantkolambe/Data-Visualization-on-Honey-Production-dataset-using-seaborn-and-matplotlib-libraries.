# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# # Domain: Food and agriculture

# %% [markdown]
# ## Context:
# ### In 2006, a global concern was raised over the rapid decline in the honeybee population, an integral component to American honey agriculture. Large numbers of hives were lost to “Colony-Collapse-Disorder”, a phenomenon of disappearing “worker-bees” causing the remaining “hive-colony” to collapse. Speculation around the cause of this disorder points to hive-diseases and pesticides harming the pollinators, though no overall consensus has been reached. Twelve years later, some industries are observing recovery but thAmerican honey industry is still largely struggling. The U.S. used to locally produce over half the honey itconsumes per year. Now, honey mostly comes from overseas, with 350 of the 400 million pounds of honeyconsumed every year originating from imports. This dataset provides insight into honey production supply anddemand in America by state from 1998 to 2012.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
# Read the dataset
df = pd.read_csv('C:/Users/Admin/Downloads/honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
print(df.head())
print(df.info())
print(df.shape)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
# ...

# %% [markdown]
# ### 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
# Calculate the percentage distribution of data in each year
year_counts = df['year'].value_counts(normalize=True) * 100

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Percentage Distribution of Data in Each Year")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ### 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
# Plot the distribution of "price per lb"
plt.figure(figsize=(10, 6))
sns.displot(data=df, x='priceperlb', kde=True)
plt.title('Distribution of Price per lb')
plt.xlabel('Price per lb')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, andwrite your findings

# %%
# Plot the relationship between 'numcol' and 'prodval' using a scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='numcol', y='prodvalue')
plt.title('Relationship between Number of Colonies and Production Value')
plt.xlabel('Number of Colonies')
plt.ylabel('Production Value')
plt.show()

# %% [markdown]
# ## INFER:
# ### In the production values 1 and numbers of colonies 100000 are the good relationship to each other.

# %% [markdown]
# ### 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings

# %%
# Plot the relationship between 'year' and 'prodvalue' using a boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='year', y='prodvalue')
plt.title('Relationship between Year and Production Value')
plt.xlabel('Year')
plt.ylabel('Production Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# Select the columns of interest
columns_of_interest = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']
df_selected = df[columns_of_interest]

# Plot the pairplot
sns.pairplot(df_selected, hue='year')
plt.title('Pairwise Relationships of Variables by Year')
plt.show()

# %% [markdown]
# ### 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
# Select the columns of interest
columns_of_interest = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
df_selected = df[columns_of_interest]

# Calculate the correlation matrix
correlation_matrix = df_selected.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
